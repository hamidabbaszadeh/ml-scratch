# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from pca import PCA

# %%
data = datasets.load_digits()
#data = datasets.load_iris()
X = data.data
y = data.target

# %%
# Project the data onto the 2 primary principal components
pca = PCA(2)
pca.fit(X)
X_projected = pca.transform(X)

print('Shape of X:', X.shape)
print('Shape of transfomed X:', X_projected.shape)
# Out:
# Shape of X: (1797, 64)
# Shape of transfomed X: (1797, 2)

# %%
x1 = X_projected[:, 0]
x2 = X_projected[:, 1]

# %%
plt.scatter(
    x1,
    x2,
    c=y,
    edgecolor="none",
    alpha=0.8,
    cmap=plt.colormaps("viridis", 3)
    )

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_27338/3644986949.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   x1, x2, c=y, edgecolor="none", alpha=0.8, cmap=plt.cm.get_cmap("viridis", 3)
